# %%
### Question 1

import pandas as pd

fifa= pd.read_csv("/content/fifa19 (1).csv")

# %%
### Question 2

fifa.head(12)
# Out:
#     Unnamed: 0      ID               Name  Age  \
# 0            0  158023           L. Messi   31
# 1            1   20801  Cristiano Ronaldo   33
# 2            2  190871          Neymar Jr   26
# 3            3  193080             De Gea   27
# 4            4  192985       K. De Bruyne   27
# 5            5  183277          E. Hazard   27
# 6            6  177003          L. Modrić   32
# 7            7  176580          L. Suárez   31
# 8            8  155862       Sergio Ramos   32
# 9            9  200389           J. Oblak   25
# 10          10  188545     R. Lewandowski   29
# 11          11  182521           T. Kroos   28
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1    https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2   https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3   https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
### QUESTION 3
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %%
### Question 4

print(fifa.shape, fifa.size)
# Out:
# (18207, 89) 1620423

# %%
#### Questiomn 5

a=fifa.columns.tolist()

# %%
###Question 6

fifa.loc[4999,]
# Out:
# Unnamed: 0                                                  4999
# ID                                                        202050
# Name                                                    T. Bruns
# Age                                                           26
# Photo             https://cdn.sofifa.org/players/4/19/202050.png
#                                        ...
# GKHandling                                                  11.0
# GKKicking                                                   13.0
# GKPositioning                                               14.0
# GKReflexes                                                   9.0
# Release Clause                                             €3.4M
# Name: 4999, Length: 89, dtype: object

# %%
#####Question 7
fifa[["ID"]]
# Out:
#            ID
# 0      158023
# 1       20801
# 2      190871
# 3      193080
# 4      192985
# ...       ...
# 18202  238813
# 18203  243165
# 18204  241638
# 18205  246268
# 18206  246269
#
# [18207 rows x 1 columns]

# %%
#### Question 8

fifa.sort_values(by=["Club","Name"], ascending=False)
# Out:
#        Unnamed: 0      ID             Name  Age  \
# 10524       10524  205202         W. Golla   26
# 6421         6421  222163          R. Pich   29
# 17263       17263  245485  P. Samiec-Talar   16
# 15414       15414  244532    P. Kucharczyk   21
# 5678         5678  155657       P. Celeban   33
# ...           ...     ...              ...  ...
# 874           874  187607        A. Dzyuba   29
# 5922         5922  196688         A. Corzo   29
# 11247       11247  243001      A. Cicâldău   20
# 15393       15393  245800         A. Busti   18
# 6021         6021  228203        A. Ashraf   27
#
#                                                 Photo Nationality  \
# 10524  https://cdn.sofifa.org/players/4/19/205202.png      Poland
# 6421   https://cdn.sofifa.org/players/4/19/222163.png    Slovakia
# 17263  https://cdn.sofifa.org/players/4/19/245485.png      Poland
# 15414  https://cdn.sofifa.org/players/4/19/244532.png      Poland
# ...

# %%
##### Question 9

fifa[fifa["Overall"]>90]
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
# 5           5  183277          E. Hazard   27
# 6           6  177003          L. Modrić   32
# 7           7  176580          L. Suárez   31
# 8           8  155862       Sergio Ramos   32
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# 6  https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# ...

# %%
##### Question 10

fifa.drop("Unnamed: 0", axis=1)
# Out:
#            ID                Name  Age  \
# 0      158023            L. Messi   31
# 1       20801   Cristiano Ronaldo   33
# 2      190871           Neymar Jr   26
# 3      193080              De Gea   27
# 4      192985        K. De Bruyne   27
# ...       ...                 ...  ...
# 18202  238813        J. Lundstram   19
# 18203  243165  N. Christoffersson   19
# 18204  241638           B. Worman   16
# 18205  246268      D. Walker-Rice   17
# 18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...                                               ...         ...
# ...

# %%
#### Question 11

fifa["Positioning"].unique()

fifa["Positioning"].nunique()
# Out:
# 94

# %%
##### Question 12

fifa[fifa.isna()]

nan_rows = fifa[fifa.isna().any(axis=1)]
nan_rows
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
#### Question 13

fifa["Release Clause"].fillna("unknown")
# Out:
# array(['€226.5M', '€127.1M', '€228.1M', ..., '€74K', '€101K', '€147K'],
#       dtype=object)

# %%
####question 14

fifa["Age"].agg(["mean","median","std"])
# Out:
# mean      25.122206
# median    25.000000
# std        4.669943
# Name: Age, dtype: float64

# %%
####### Question 15

fifa['ShotPower'].max()
# Out:
# 95.0

# %%
####### Qustion 16


fifa[fifa["ShotPower"]==fifa['ShotPower'].max()]
# Out:
#    Unnamed: 0     ID               Name  Age  \
# 1           1  20801  Cristiano Ronaldo   33
#
#                                            Photo Nationality  \
# 1  https://cdn.sofifa.org/players/4/19/20801.png    Portugal
#
#                                   Flag  Overall  Potential      Club  ...  \
# 1  https://cdn.sofifa.org/flags/38.png       94         94  Juventus  ...
#
#   Composure Marking StandingTackle  SlidingTackle GKDiving  GKHandling  \
# 1      95.0    28.0           31.0           23.0      7.0        11.0
#
#    GKKicking  GKPositioning GKReflexes Release Clause
# 1       15.0           14.0       11.0        €127.1M
#
# [1 rows x 89 columns]

# %%
###another easy way

fifa.loc[[fifa['ShotPower'].idxmax()]]
# Out:
#    Unnamed: 0     ID               Name  Age  \
# 1           1  20801  Cristiano Ronaldo   33
#
#                                            Photo Nationality  \
# 1  https://cdn.sofifa.org/players/4/19/20801.png    Portugal
#
#                                   Flag  Overall  Potential      Club  ...  \
# 1  https://cdn.sofifa.org/flags/38.png       94         94  Juventus  ...
#
#   Composure Marking StandingTackle  SlidingTackle GKDiving  GKHandling  \
# 1      95.0    28.0           31.0           23.0      7.0        11.0
#
#    GKKicking  GKPositioning GKReflexes Release Clause
# 1       15.0           14.0       11.0        €127.1M
#
# [1 rows x 89 columns]

# %%
##### Question 17

fifa.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...
